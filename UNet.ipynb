# %%
import os

import imageio
from PIL import Image

import matplotlib.pyplot as plt

import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import concatenate
from tensorflow.keras.losses import binary_crossentropy
from sklearn.model_selection import train_test_split

# %%
def encoder_block(inputs, n_filters=32, dropout_prob=0.3, max_pooling=True):
    conv = Conv2D(n_filters, 3, activation='relu', padding='same', kernel_initializer='HeNormal')(inputs)
    conv = Conv2D(n_filters, 3, activation='relu', padding='same', kernel_initializer='HeNormal')(conv)

    if dropout_prob > 0:
        conv = Dropout(dropout_prob)(conv)
    if max_pooling:
        next_layer = MaxPooling2D(pool_size=(2,2))(conv)
    else:
        next_layer = conv
    skip_connection = conv
    return next_layer, skip_connection

# %%
def decoder_block(prev_layer_input, skip_layer_input, n_filters=32):
    upsample = Conv2DTranspose(n_filters, (3,3), strides=(2,2), padding='same')(prev_layer_input)
    concat = concatenate([upsample, skip_layer_input], axis=3)
    conv = Conv2D(n_filters, 3, activation='relu', padding='same', kernel_initializer='he_normal')(concat)
    conv = Conv2D(n_filters, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    return conv

# %%
def UNet(input_size=(128, 128, 3), n_filters=32, n_classes=3):
    inputs = Input(input_size)
    encoder0 = encoder_block(inputs, n_filters, max_pooling=True, dropout_prob=0)
    encoder1 = encoder_block(encoder0[0], n_filters*2, max_pooling=True, dropout_prob=0)
    encoder2 = encoder_block(encoder1[0], n_filters*4, max_pooling=True, dropout_prob=0)
    encoder3 = encoder_block(encoder2[0], n_filters*8, max_pooling=True, dropout_prob=0.3)
    encoder4 = encoder_block(encoder3[0], n_filters*16, max_pooling=False, dropout_prob=0.3)

    decoder_block5 = decoder_block(encoder4[0], encoder3[1], n_filters*8)
    decoder_block6 = decoder_block(decoder_block5, encoder2[1], n_filters*4)
    decoder_block7 = decoder_block(decoder_block6, encoder1[1], n_filters*2)
    decoder_block8 = decoder_block(decoder_block7, encoder0[1], n_filters)

    conv9 = Conv2D(n_filters, 3, activation='relu', padding='same', kernel_initializer='he_normal')(decoder_block8)
    conv10 = Conv2D(n_classes, 1, padding='same')(conv9)

    model = tf.keras.Model(inputs=inputs, outputs=conv10)
    
    return model

# %%
model = UNet(n_filters=32, n_classes=3)
model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_24 (InputLayer)          [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_310 (Conv2D)            (None, 128, 128, 32  896         ['input_24[0][0]']
#                                 )
#
#  conv2d_311 (Conv2D)            (None, 128, 128, 32  9248        ['conv2d_310[0][0]']
#                                 )
#
#  max_pooling2d_107 (MaxPooling2  (None, 64, 64, 32)  0           ['conv2d_311[0][0]']
#  D)
#
#  conv2d_312 (Conv2D)            (None, 64, 64, 64)   18496       ['max_pooling2d_107[0][0]']
#
#  conv2d_313 (Conv2D)            (None, 64, 64, 64)   36928       ['conv2d_312[0][0]']
#
#  max_pooling2d_108 (MaxPooling2  (None, 32, 32, 64)  0           ['conv2d_313[0][0]']
#  D)
#
#  conv2d_314 (Conv2D)            (None, 32, 32, 128)  73856       ['max_pooling2d_108[0][0]']
#
#  conv2d_315 (Conv2D)            (None, 32, 32, 128)  147584      ['conv2d_314[0][0]']
#
#  max_pooling2d_109 (MaxPooling2  (None, 16, 16, 128)  0          ['conv2d_315[0][0]']
#  D)
#
#  conv2d_316 (Conv2D)            (None, 16, 16, 256)  295168      ['max_pooling2d_109[0][0]']
#
#  conv2d_317 (Conv2D)            (None, 16, 16, 256)  590080      ['conv2d_316[0][0]']
#
#  dropout_67 (Dropout)           (None, 16, 16, 256)  0           ['conv2d_317[0][0]']
#
#  max_pooling2d_110 (MaxPooling2  (None, 8, 8, 256)   0           ['dropout_67[0][0]']
#  D)
#
#  conv2d_318 (Conv2D)            (None, 8, 8, 512)    1180160     ['max_pooling2d_110[0][0]']
#
#  conv2d_319 (Conv2D)            (None, 8, 8, 512)    2359808     ['conv2d_318[0][0]']
#
#  dropout_68 (Dropout)           (None, 8, 8, 512)    0           ['conv2d_319[0][0]']
#
#  conv2d_transpose_47 (Conv2DTra  (None, 16, 16, 256)  1179904    ['dropout_68[0][0]']
#  nspose)
#
#  concatenate_47 (Concatenate)   (None, 16, 16, 512)  0           ['conv2d_transpose_47[0][0]',
#                                                                   'dropout_67[0][0]']
#
#  conv2d_320 (Conv2D)            (None, 16, 16, 256)  1179904     ['concatenate_47[0][0]']
#
#  conv2d_321 (Conv2D)            (None, 16, 16, 256)  590080      ['conv2d_320[0][0]']
#
#  conv2d_transpose_48 (Conv2DTra  (None, 32, 32, 128)  295040     ['conv2d_321[0][0]']
#  nspose)
#
#  concatenate_48 (Concatenate)   (None, 32, 32, 256)  0           ['conv2d_transpose_48[0][0]',
#                                                                   'conv2d_315[0][0]']
#
#  conv2d_322 (Conv2D)            (None, 32, 32, 128)  295040      ['concatenate_48[0][0]']
#
#  conv2d_323 (Conv2D)            (None, 32, 32, 128)  147584      ['conv2d_322[0][0]']
#
#  conv2d_transpose_49 (Conv2DTra  (None, 64, 64, 64)  73792       ['conv2d_323[0][0]']
#  nspose)
#
#  concatenate_49 (Concatenate)   (None, 64, 64, 128)  0           ['conv2d_transpose_49[0][0]',
#                                                                   'conv2d_313[0][0]']
#
#  conv2d_324 (Conv2D)            (None, 64, 64, 64)   73792       ['concatenate_49[0][0]']
#
#  conv2d_325 (Conv2D)            (None, 64, 64, 64)   36928       ['conv2d_324[0][0]']
#
#  conv2d_transpose_50 (Conv2DTra  (None, 128, 128, 32  18464      ['conv2d_325[0][0]']
#  nspose)                        )
#
#  concatenate_50 (Concatenate)   (None, 128, 128, 64  0           ['conv2d_transpose_50[0][0]',
#                                 )                                 'conv2d_311[0][0]']
#
#  conv2d_326 (Conv2D)            (None, 128, 128, 32  18464       ['concatenate_50[0][0]']
#                                 )
#
#  conv2d_327 (Conv2D)            (None, 128, 128, 32  9248        ['conv2d_326[0][0]']
#                                 )
#
#  conv2d_328 (Conv2D)            (None, 128, 128, 32  9248        ['conv2d_327[0][0]']
#                                 )
#
#  conv2d_329 (Conv2D)            (None, 128, 128, 3)  99          ['conv2d_328[0][0]']
#
# ==================================================================================================
# Total params: 8,639,811
# Trainable params: 8,639,811
# Non-trainable params: 0
# __________________________________________________________________________________________________
